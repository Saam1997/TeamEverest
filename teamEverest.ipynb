# %%
import requests
import json

url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.json?limit=200&api_key=hOhqA3e7f7PZBLv4PjXX0LSuIimqqWT9v50roebU" # Replace with your API endpoint
##url = "https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?limit=200&api_key=hOhqA3e7f7PZBLv4PjXX0LSuIimqqWT9v50roebU&location=1617+Cole+Blvd+Golden+CO" 

#https://developer.nrel.gov/api/alt-fuel-stations/v1/nearest.json?api_key=DEMO_KEY&location=1617+Cole+Blvd+Golden+CO&fuel_type=ELEC&limit=1
#url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.json?limit=1&api_key=hOhqA3e7f7PZBLv4PjXX0LSuIimqqWT9v50roebU&fuel_type_code=ELEC"
# Set the request headers and parameters, if any
#headers = {"Authorization": "hOhqA3e7f7PZBLv4PjXX0LSuIimqqWT9v50roebU"}
params = {"param1": "fuel_type", "param2": "cards_accepted"}

# Make the API call using the GET method
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Get the response content as a JSON object
    data = response.json()
    #data=response.text
    # Process the data as needed
    print(data)
    
    
else:
    # If the request failed, print the status code and error message
    print("Error:", response.status_code, response.text)

# %%
print(json.dumps(data, indent=4))

# %%
print(len(data))
# Out:
# 4

# %%
fuel_types = ["ELEC", "HY", "BD", "RD", "E85"]

# %%
filtered_data = [station for station in data['fuel_stations'] if station['fuel_type_code'] in fuel_types]

# %%
print(json.dumps(filtered_data, indent=4))
#data = filtered_data.json()
    # Process the data as needed
#print(data)
# Out:
# [
#     {
#         "access_code": "private",
#         "access_days_time": null,
#         "access_detail_code": "GOVERNMENT",
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-03-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Private - Government only",
#         "id": 1436,
#         "open_date": "1993-09-15",
#         "owner_type_code": "SG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "Nebraska Department of Transportation",
#         "station_phone": null,
#         "updated_at": "2023-03-21T21:43:31Z",
#         "facility_type": "STATE_GOV",
#         "geocode_status": "200-8",
#         "latitude": 40.856204,
#         "longitude": -96.717819,
#         "city": "Lincoln",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "NE",
#         "street_address": "302 Superior St",
#         "zip": "68521",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E15"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": null,
#         "access_detail_code": "GOVERNMENT",
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-03-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Private - Government only",
#         "id": 1437,
#         "open_date": "1993-01-15",
#         "owner_type_code": "SG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "Nebraska Transportation Services Bureau - Dispatch Building",
#         "station_phone": null,
#         "updated_at": "2023-03-22T18:32:56Z",
#         "facility_type": "STATE_GOV",
#         "geocode_status": "GPS",
#         "latitude": 40.811394,
#         "longitude": -96.699689,
#         "city": "Lincoln",
#         "intersection_directions": "At motor pool behind state parking garage.",
#         "plus4": null,
#         "state": "NE",
#         "street_address": "M St & Centennial Mall S",
#         "zip": "68508",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E15"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": null,
#         "access_detail_code": "GOVERNMENT",
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-03-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Private - Government only",
#         "id": 1441,
#         "open_date": "1993-09-15",
#         "owner_type_code": "SG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "Nebraska Department of Transportation",
#         "station_phone": null,
#         "updated_at": "2023-03-22T18:19:40Z",
#         "facility_type": "STATE_GOV",
#         "geocode_status": "200-8",
#         "latitude": 40.91701,
#         "longitude": -98.379743,
#         "city": "Grand Island",
#         "intersection_directions": "At intersection of US Highway 30 and 281.",
#         "plus4": null,
#         "state": "NE",
#         "street_address": "3305 Old Potash Hwy",
#         "zip": "68803",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E15"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "7am-6pm M-F, 7am-5pm Sat",
#         "access_detail_code": "CREDIT_CARD_AFTER_HOURS",
#         "cards_accepted": "A Cash Checks D M V Voyager Wright_Exp",
#         "date_last_confirmed": "2022-09-14",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Public - Credit card after hours",
#         "id": 1447,
#         "open_date": "1993-11-15",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Sioux Valley Co-op - Cenex",
#         "station_phone": "605-886-5829",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "COOP",
#         "geocode_status": "200-9",
#         "latitude": 44.904113,
#         "longitude": -97.130798,
#         "city": "Watertown",
#         "intersection_directions": "On Highway 20 at 3rd Street NW",
#         "plus4": null,
#         "state": "SD",
#         "street_address": "220 10th St NW",
#         "zip": "57201",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E30-E35"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit apr\u00e8s les heures d'ouverture",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "6am-10pm M-Sat, 8am-10pm Sun",
#         "access_detail_code": "CREDIT_CARD_AFTER_HOURS",
#         "cards_accepted": "A Cash D M V Wright_Exp",
#         "date_last_confirmed": "2022-08-10",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Public - Credit card after hours",
#         "id": 1451,
#         "open_date": "1993-11-15",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "F&M Co-op Oil",
#         "station_phone": "605-256-4516",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "COOP",
#         "geocode_status": "200-8",
#         "latitude": 44.00769,
#         "longitude": -97.146785,
#         "city": "Madison",
#         "intersection_directions": "At Highway 81",
#         "plus4": null,
#         "state": "SD",
#         "street_address": "45316 Highway 34",
#         "zip": "57042",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E20-E25",
#             "E30-E35"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit apr\u00e8s les heures d'ouverture",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": null,
#         "access_detail_code": "GOVERNMENT",
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-03-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Private - Government only",
#         "id": 1459,
#         "open_date": "1993-09-15",
#         "owner_type_code": "SG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "Nebraska Department of Transportation",
#         "station_phone": null,
#         "updated_at": "2023-03-21T21:43:42Z",
#         "facility_type": "STATE_GOV",
#         "geocode_status": "200-8",
#         "latitude": 40.762848,
#         "longitude": -96.701622,
#         "city": "Lincoln",
#         "intersection_directions": "At Highway 2.",
#         "plus4": null,
#         "state": "NE",
#         "street_address": "5001 S 14th St",
#         "zip": "68512",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E15"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily",
#         "access_detail_code": null,
#         "cards_accepted": "A Cash D FuelMan M V Voyager Wright_Exp",
#         "date_last_confirmed": "2022-03-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Public",
#         "id": 1479,
#         "open_date": "1990-01-15",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Texaco - Highway 34 Truckstop",
#         "station_phone": "319-752-3894",
#         "updated_at": "2023-04-14T18:36:02Z",
#         "facility_type": "TRUCK_STOP",
#         "geocode_status": "200-9",
#         "latitude": 40.825493,
#         "longitude": -91.208355,
#         "city": "West Burlington",
#         "intersection_directions": "At Highway 406 and 34",
#         "plus4": null,
#         "state": "IA",
#         "street_address": "4305 W Mount Pleasant St",
#         "zip": "52655",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": false,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "5:30am-12am daily",
#         "access_detail_code": "CREDIT_CARD_AFTER_HOURS",
#         "cards_accepted": "A Cash D M V",
#         "date_last_confirmed": "2021-06-07",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Public - Credit card after hours",
#         "id": 1480,
#         "open_date": "2006-01-15",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Conoco - Convenient Food Mart",
#         "station_phone": "573-893-3278",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "CONVENIENCE_STORE",
#         "geocode_status": "200-9",
#         "latitude": 38.588189,
#         "longitude": -92.255887,
#         "city": "Jefferson City",
#         "intersection_directions": "Off of Highway 50.",
#         "plus4": null,
#         "state": "MO",
#         "street_address": "3714 W Truman Blvd",
#         "zip": "65109",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": true,
#         "e85_other_ethanol_blends": [
#             "E30-E35",
#             "E40-Plus"
#         ],
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit apr\u00e8s les heures d'ouverture",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily",
#         "access_detail_code": null,
#         "cards_accepted": "A Cash D M V Voyager Wright_Exp",
#         "date_last_confirmed": "2022-08-10",
#         "expected_date": null,
#         "fuel_type_code": "E85",
#         "groups_with_access_code": "Public",
#         "id": 1487,
#         "open_date": "2005-06-15",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Flying J",
#         "station_phone": "605-342-5450",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "CONVENIENCE_STORE",
#         "geocode_status": "200-9",
#         "latitude": 44.103769,
#         "longitude": -103.14969,
#         "city": "Rapid City",
#         "intersection_directions": "Exit 61",
#         "plus4": null,
#         "state": "SD",
#         "street_address": "4200 N I-90 Service Rd",
#         "zip": "57709",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": false,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": null,
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": null,
#         "ev_network": null,
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1517,
#         "open_date": "1999-10-15",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Truesdale Center",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "GPS",
#         "latitude": 34.2483191527193,
#         "longitude": -118.3879713743439,
#         "city": "Sun Valley",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "11797 Truesdale St",
#         "zip": "91352",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "CHADEMO",
#             "J1772",
#             "J1772COMBO"
#         ],
#         "ev_dc_fast_num": 3,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 39,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": null,
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1519,
#         "open_date": "2020-02-28",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - West LA District Office",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "200-8",
#         "latitude": 34.052542,
#         "longitude": -118.448504,
#         "city": "Los Angeles",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "1394 S Sepulveda Blvd",
#         "zip": "90024",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 4,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "5:30am-9pm; pay lot",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 1523,
#         "open_date": "1995-08-30",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Los Angeles Convention Center",
#         "station_phone": "213-741-1151",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "PARKING_GARAGE",
#         "geocode_status": "GPS",
#         "latitude": 34.040539,
#         "longitude": -118.271387,
#         "city": "Los Angeles",
#         "intersection_directions": "West hall and South hall",
#         "plus4": null,
#         "state": "CA",
#         "street_address": "1201 S Figueroa St",
#         "zip": "90015",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 7,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free; parking fee",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "For fleet and employee use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1525,
#         "open_date": "1999-10-15",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - John Ferraro Building",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "GPS",
#         "latitude": 34.059133,
#         "longitude": -118.248589,
#         "city": "Los Angeles",
#         "intersection_directions": "Across Hope",
#         "plus4": null,
#         "state": "CA",
#         "street_address": "111 N Hope St",
#         "zip": "90012",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "CHADEMO",
#             "J1772",
#             "J1772COMBO"
#         ],
#         "ev_dc_fast_num": 2,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 311,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1531,
#         "open_date": "2018-05-01",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Haynes Power Plant",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "GPS",
#         "latitude": 33.759802,
#         "longitude": -118.096665,
#         "city": "Long Beach",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "6801 E 2nd St",
#         "zip": "90803",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "CHADEMO",
#             "J1772",
#             "J1772COMBO"
#         ],
#         "ev_dc_fast_num": 1,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 19,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1552,
#         "open_date": "1999-10-15",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Harbor Generating Station",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "200-8",
#         "latitude": 33.770508,
#         "longitude": -118.265628,
#         "city": "Wilmington",
#         "intersection_directions": "At B St",
#         "plus4": null,
#         "state": "CA",
#         "street_address": "161 N Island Ave",
#         "zip": "90744",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 10,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": "GOVERNMENT",
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private - Government only",
#         "id": 1556,
#         "open_date": "2016-01-01",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Sylmar West",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "200-8",
#         "latitude": 34.30309,
#         "longitude": -118.480505,
#         "city": "Sylmar",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "13201 Sepulveda Blvd",
#         "zip": "91342",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 2,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet and employee use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1572,
#         "open_date": "1999-10-15",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - EV Service Center",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "200-8",
#         "latitude": 34.066801,
#         "longitude": -118.227605,
#         "city": "Los Angeles",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "1630 N Main St",
#         "zip": "90012",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "CHADEMO",
#             "J1772"
#         ],
#         "ev_dc_fast_num": 1,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 46,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1573,
#         "open_date": "2019-04-01",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Fairfax Center",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "200-8",
#         "latitude": 34.036777,
#         "longitude": -118.368841,
#         "city": "Los Angeles",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "2311 S Fairfax Ave",
#         "zip": "90016",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 13,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Priv\u00e9",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-09-14",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 1583,
#         "open_date": "1996-10-15",
#         "owner_type_code": "SG",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "California Air Resources Board",
#         "station_phone": "626-575-6800",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "STATE_GOV",
#         "geocode_status": "GPS",
#         "latitude": 34.06872,
#         "longitude": -118.064,
#         "city": "El Monte",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "9530 Telstar Ave",
#         "zip": "91731",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 3,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "private",
#         "access_days_time": "Fleet use only",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Private",
#         "id": 1589,
#         "open_date": "1999-10-15",
#         "owner_type_code": "LG",
#         "status_code": "E",
#         "restricted_access": null,
#         "station_name": "LADWP - Palmetto Center",
#         "station_phone": null,
#         "updated_at": "2023-02-15T22:45:41Z",
#         "facility_type": "UTILITY",
#         "geocode_status": "GPS",
#         "latitude": 34.039736,
#         "longitude": -118.236065,
#         "city": "Los Angeles",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "1212 Palmetto St",
#         "zip": "90013",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
# ...
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "Mon 5:00am - 10:59pm; Tue 5:00am - 10:59pm; Wed 5:00am - 10:59pm; Thu 5:00am - 10:59pm; Fri 5:00am - 10:59pm; Sat 5:00am - 10:59pm; Sun 5:00am - 10:59pm",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-04-21",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 7233,
#         "open_date": "1998-05-30",
#         "owner_type_code": null,
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Westfield Parking Garage 1st Floor",
#         "station_phone": "888-264-2208",
#         "updated_at": "2023-04-21T01:24:34Z",
#         "facility_type": null,
#         "geocode_status": "GPS",
#         "latitude": 34.1564065,
#         "longitude": -118.4389655,
#         "city": "Sherman Oaks",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "14006 Riverside Dr",
#         "zip": "91423",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 2,
#         "ev_network": "Volta",
#         "ev_network_web": "https://voltacharging.com/",
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null,
#         "ev_network_ids": {
#             "station": [
#                 "49a302b2-d0c1-4b6d-b454-8601c77964ef"
#             ],
#             "posts": [
#                 "17665441-096d-45d6-85a3-6ed0f6dcef2c",
#                 "fc93d24e-b060-4fe7-894c-fe8760c4d6a3"
#             ]
#         }
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily; pay lot; see valet for access; Drivers must bring their own J1772 cordset for Level 1 charging",
#         "access_detail_code": "CALL",
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-09-14",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public - Call ahead",
#         "id": 7242,
#         "open_date": "1998-05-30",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Universal City Hilton",
#         "station_phone": "818-506-2500",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "HOTEL",
#         "geocode_status": "200-8",
#         "latitude": 34.138717,
#         "longitude": -118.35904,
#         "city": "Universal City",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "333 Universal Terrace Pkwy",
#         "zip": "91608",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "NEMA520"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": 1,
#         "ev_level2_evse_num": null,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public - Appeler \u00e0 l'avance",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": null,
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-04-21",
#         "expected_date": "2022-09-30",
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "TEMPORARILY UNAVAILABLE (Public)",
#         "id": 7245,
#         "open_date": "1998-06-30",
#         "owner_type_code": null,
#         "status_code": "T",
#         "restricted_access": null,
#         "station_name": "Van Nuys Station",
#         "station_phone": "866-816-7584",
#         "updated_at": "2023-04-21T01:22:38Z",
#         "facility_type": null,
#         "geocode_status": "GPS",
#         "latitude": 34.211366,
#         "longitude": -118.448346,
#         "city": "Van Nuys",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "7724 Van Nuys Blvd",
#         "zip": "91405",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 4,
#         "ev_network": "EV Connect",
#         "ev_network_web": "http://evconnect.com/",
#         "ev_other_evse": null,
#         "ev_pricing": null,
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "TEMPORAIREMENT SUSPENDU (Public)",
#         "ev_pricing_fr": null,
#         "ev_network_ids": {
#             "station": [
#                 "a5e414a5-84c2-46c9-b73d-09f26a0c8309"
#             ],
#             "posts": [
#                 "63340367769d34776391e959",
#                 "63340367769d34776391e9b7",
#                 "63340367769d34776391ec46",
#                 "63340367769d34776391ecc1"
#             ]
#         }
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2022-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 7250,
#         "open_date": "1998-06-15",
#         "owner_type_code": "T",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Office Max - Home Depot",
#         "station_phone": "562-806-6600",
#         "updated_at": "2022-02-10T19:42:29Z",
#         "facility_type": "SHOPPING_CENTER",
#         "geocode_status": "200-8",
#         "latitude": 33.94756,
#         "longitude": -118.153806,
#         "city": "Downey",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "7075 Firestone Blvd",
#         "zip": "90241",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 4,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily; pay lot; see valet for access",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2021-12-09",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 7280,
#         "open_date": "1998-07-01",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Hyatt at Fisherman's Wharf",
#         "station_phone": "415-563-1234",
#         "updated_at": "2022-02-10T19:42:29Z",
#         "facility_type": "HOTEL",
#         "geocode_status": "GPS",
#         "latitude": 37.80619,
#         "longitude": -122.4152,
#         "city": "San Francisco",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "555 N Point St",
#         "zip": "94133",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 1,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     },
#     {
#         "access_code": "public",
#         "access_days_time": "24 hours daily",
#         "access_detail_code": null,
#         "cards_accepted": null,
#         "date_last_confirmed": "2023-01-10",
#         "expected_date": null,
#         "fuel_type_code": "ELEC",
#         "groups_with_access_code": "Public",
#         "id": 7286,
#         "open_date": "2019-11-01",
#         "owner_type_code": "P",
#         "status_code": "E",
#         "restricted_access": false,
#         "station_name": "Arden Fair Mall",
#         "station_phone": "916-920-1167",
#         "updated_at": "2023-02-14T15:54:11Z",
#         "facility_type": "SHOPPING_MALL",
#         "geocode_status": "200-8",
#         "latitude": 38.599693,
#         "longitude": -121.427045,
#         "city": "Sacramento",
#         "intersection_directions": null,
#         "plus4": null,
#         "state": "CA",
#         "street_address": "1689 Arden Way",
#         "zip": "95815",
#         "country": "US",
#         "bd_blends": null,
#         "cng_dispenser_num": null,
#         "cng_fill_type_code": null,
#         "cng_psi": null,
#         "cng_renewable_source": null,
#         "cng_total_compression": null,
#         "cng_total_storage": null,
#         "cng_vehicle_class": null,
#         "cng_has_rng": null,
#         "e85_blender_pump": null,
#         "e85_other_ethanol_blends": null,
#         "ev_connector_types": [
#             "J1772"
#         ],
#         "ev_dc_fast_num": null,
#         "ev_level1_evse_num": null,
#         "ev_level2_evse_num": 4,
#         "ev_network": "Non-Networked",
#         "ev_network_web": null,
#         "ev_other_evse": null,
#         "ev_pricing": "Free",
#         "ev_renewable_source": null,
#         "hy_is_retail": null,
#         "hy_pressures": null,
#         "hy_standards": null,
#         "hy_status_link": null,
#         "lng_renewable_source": null,
#         "lng_vehicle_class": null,
#         "lng_has_rng": null,
#         "lpg_primary": null,
#         "lpg_nozzle_types": null,
#         "ng_fill_type_code": null,
#         "ng_psi": null,
#         "ng_vehicle_class": null,
#         "rd_blends": null,
#         "rd_blends_fr": null,
#         "rd_blended_with_biodiesel": null,
#         "rd_max_biodiesel_level": null,
#         "nps_unit_name": null,
#         "access_days_time_fr": null,
#         "intersection_directions_fr": null,
#         "bd_blends_fr": null,
#         "groups_with_access_code_fr": "Public",
#         "ev_pricing_fr": null
#     }
# ]

# %%
import csv
#response = requests.get(url)

# Output JSON file path
json_file = 'output.json'

# Write JSON data to file
with open(json_file, 'w') as file:
    json.dump(filtered_data, file)

# %%
# load JSON data into a pandas DataFrame
with open('output.json', 'r') as f:
    data = pd.read_json(f)

# convert DataFrame to CSV and save it
data.to_csv('jsonfile.csv', index=False)

# %%
# googleapi=AIzaSyAPxR8MGKEIN_Qs29ROwtAed_TBZzs7mqY

# %%
api_key = 'AIzaSyAPxR8MGKEIN_Qs29ROwtAed_TBZzs7mqY'

# %%
from bokeh.io import output_notebook
output_notebook()
bokeh_width, bokeh_height = 500,400
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p3806">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.io import show
from bokeh.plotting import gmap
from bokeh.models import GMapOptions

# %%
lat, lon =45.560230, -94.172852

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='EV Charging', 
             width=bokeh_width, height=bokeh_height)
    show(p)
    return p

# %%
p = plot(lat, lon)
# Out:
#   <div id="7786bd6e-83ae-44f1-8670-e1716d592077" data-root-id="p3808" style="display: contents;"></div>

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='EV Charging', 
             width=bokeh_width, height=bokeh_height)
    # beware, longitude is on the x axis ;-)
    center = p.circle([lng], [lat], size=10, alpha=0.5, color='red')
    show(p)
    return p

p = plot(lat, lon, map_type='terrain')
# Out:
#   <div id="497a0d76-31e0-436b-bc94-22d9538c8850" data-root-id="p4024" style="display: contents;"></div>

# %%
import pandas as pd

df = pd.read_csv('jsonfile.csv')
df.head()
# Out:
#   access_code              access_days_time       access_detail_code  \
# 0     private                           NaN               GOVERNMENT
# 1     private                           NaN               GOVERNMENT
# 2     private                           NaN               GOVERNMENT
# 3      public      7am-6pm M-F, 7am-5pm Sat  CREDIT_CARD_AFTER_HOURS
# 4      public  6am-10pm M-Sat, 8am-10pm Sun  CREDIT_CARD_AFTER_HOURS
#
#                            cards_accepted date_last_confirmed expected_date  \
# 0                                     NaN          2022-03-07           NaN
# 1                                     NaN          2022-03-07           NaN
# 2                                     NaN          2022-03-07           NaN
# 3  A Cash Checks D M V Voyager Wright_Exp          2022-09-14           NaN
# 4                 A Cash D M V Wright_Exp          2022-08-10           NaN
#
#   fuel_type_code           groups_with_access_code    id   open_date  ...  \
# 0            E85         Private - Government only  1436  1993-09-15  ...
# 1            E85         Private - Government only  1437  1993-01-15  ...
# 2            E85         Private - Government only  1441  1993-09-15  ...
# 3            E85  Public - Credit card after hours  1447  1993-11-15  ...
# 4            E85  Public - Credit card after hours  1451  1993-11-15  ...
#
#   rd_blends_fr rd_blended_with_biodiesel  rd_max_biodiesel_level  \
# 0          NaN                       NaN                     NaN
# 1          NaN                       NaN                     NaN
# 2          NaN                       NaN                     NaN
# 3          NaN                       NaN                     NaN
# 4          NaN                       NaN                     NaN
#
#   nps_unit_name access_days_time_fr intersection_directions_fr bd_blends_fr  \
# 0           NaN                 NaN                        NaN          NaN
# 1           NaN                 NaN                        NaN          NaN
# 2           NaN                 NaN                        NaN          NaN
# 3           NaN                 NaN                        NaN          NaN
# 4           NaN                 NaN                        NaN          NaN
#
#                           groups_with_access_code_fr  ev_pricing_fr  \
# 0                    Privé - Réservé au gouvernement            NaN
# 1                    Privé - Réservé au gouvernement            NaN
# 2                    Privé - Réservé au gouvernement            NaN
# 3  Public - Carte de crédit après les heures d'ou...            NaN
# 4  Public - Carte de crédit après les heures d'ou...            NaN
#
#    ev_network_ids
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 70 columns]

# %%
df.shape
# Out:
# (47, 70)

# %%
from bokeh.models import ColumnDataSource

def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    p = gmap(api_key, gmap_options, title='EV Charging', 
             width=bokeh_width, height=bokeh_height)
    # definition of the column data source: 
    source = ColumnDataSource(df)
    # see how we specify the x and y columns as strings, 
    # and how to declare as a source the ColumnDataSource:
    center = p.circle('longitude', 'latitude', size=4, alpha=0.2, 
                      color='red', source=source)
    show(p)
    return p

p = plot(lat, lon, map_type='roadmap')
# Out:
#   <div id="793b58ee-2d06-4b50-a7d0-bc90db3a00e0" data-root-id="p4285" style="display: contents;"></div>

# %%
def plot(lat, lng, zoom=10, map_type='roadmap'):
    gmap_options = GMapOptions(lat=lat, lng=lng, 
                               map_type=map_type, zoom=zoom)
    # the tools are defined below: 
    p = gmap(api_key, gmap_options, title='EV Charging', 
             width=bokeh_width, height=bokeh_height,
             tools=['hover', 'reset', 'wheel_zoom', 'pan'])
    source = ColumnDataSource(df)
    center = p.circle('longitude', 'latitude', size=4, alpha=0.5, 
                      color='red', source=source)
    show(p)
    return p

p = plot(lat, lon, map_type='roadmap', zoom=12)
# Out:
#   <div id="9cfe37d3-8874-4a20-a744-7aff51c294aa" data-root-id="p4916" style="display: contents;"></div>
